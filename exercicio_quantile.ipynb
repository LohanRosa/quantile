# %% [markdown]
# <a href="https://colab.research.google.com/github/LohanRosa/quantile/blob/main/exercicio_quantile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded =  files.upload()
# Out:
#      <input type="file" id="files-deb66bc2-8888-4a4b-acc6-de465c88e8ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-deb66bc2-8888-4a4b-acc6-de465c88e8ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
df =  pd.read_csv('df_exemplo_m2w1.csv',  delim_whitespace=True)

# %%
df.head()
# Out:
#       Sta_ID                                Depth_ID  Depthm  T_degC  O2Sat  \
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0000B-3       0   10.30   92.8
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0006A-3       6   18.46  111.8
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0010A-7      10   10.29   95.0
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0015A-3      15   10.29   95.3
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0020A-7      20   10.33   95.1
#
#       Salnty
# 44.0  33.030
# 44.0  32.920
# 44.0  32.951
# 44.0  32.990
# 44.0  33.005

# %%
df.T
# Out:
#                                             44.0  \
# Sta_ID                                      48.5
# Depth_ID  19-4904CR-HY-087-0606-04400485-0000B-3
# Depthm                                         0
# T_degC                                      10.3
# O2Sat                                       92.8
# Salnty                                     33.03
#
#                                             44.0  \
# Sta_ID                                      48.5
# Depth_ID  19-4904CR-HY-087-0606-04400485-0006A-3
# Depthm                                         6
# T_degC                                     18.46
# O2Sat                                      111.8
# Salnty                                     32.92
#
#                                             44.0  \
# Sta_ID                                      48.5
# Depth_ID  19-4904CR-HY-087-0606-04400485-0010A-7
# Depthm                                        10
# T_degC                                     10.29
# ...

# %%
df.shape
# Out:
# (774, 6)

# %%
df.head()
# Out:
#       Sta_ID                                Depth_ID  Depthm  T_degC  O2Sat  \
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0000B-3       0   10.30   92.8
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0006A-3       6   18.46  111.8
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0010A-7      10   10.29   95.0
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0015A-3      15   10.29   95.3
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0020A-7      20   10.33   95.1
#
#       Salnty
# 44.0  33.030
# 44.0  32.920
# 44.0  32.951
# 44.0  32.990
# 44.0  33.005

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 774 entries, 44.0 to 36.7
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sta_ID    774 non-null    float64
#  1   Depth_ID  774 non-null    object
#  2   Depthm    774 non-null    int64
#  3   T_degC    774 non-null    float64
#  4   O2Sat     774 non-null    float64
#  5   Salnty    774 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 58.5+ KB

# %%
df.describe()
# Out:
#            Sta_ID       Depthm      T_degC       O2Sat      Salnty
# count  774.000000   774.000000  774.000000  774.000000  774.000000
# mean    87.118863   341.350129    8.229354   50.802842   33.601654
# std     19.069087   350.328591    3.929834   37.697035    0.656640
# min     48.500000     0.000000    2.880000    3.400000   32.160000
# 25%     68.000000    62.000000    4.865000    9.725000   32.900000
# 50%     77.000000   200.000000    7.710000   45.050000   33.848500
# 75%     96.000000   587.250000   10.285000   92.100000   34.187000
# max    115.000000  1316.000000   18.700000  120.000000   34.520000

# %%
df["Salnty"].mean()
# Out:
# 33.601653746770026

# %%
df["Salnty"].std()
# Out:
# 0.6566401437630878

# %%
df["Salnty"].median()
# Out:
# 33.8485

# %%
df["Salnty"].min()
# Out:
# 32.16

# %%
df["Salnty"].quantile(0.25)
# Out:
# 32.9

# %%
df["Salnty"].quantile(0.50)
# Out:
# 33.8485

# %%
df["Salnty"].quantile(0.75)
# Out:
# 34.187

# %%
df["Salnty"].max()
# Out:
# 34.52

# %%
df["Salnty"].mode()
# Out:
# 0    32.74
# dtype: float64
